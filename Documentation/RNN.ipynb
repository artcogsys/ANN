# %%
# %matplotlib inline

import sys
sys.path.append('/Users/marcelvangerven/Code/github/ANN')

import rnn
import numpy as np
from chainer import optimizers
import chainer.links as L
import chainer.functions as F
import matplotlib.pyplot as plt

# %%
epochs = 50 # epoch number.
n = 12 # minibatch size.

# %%
X = np.ones((1,100,1)).astype(np.float32)
T = np.ones((1,100,1)).astype(np.float32)

# %%
predictor = rnn.Predictor(L.LSTM(1,3), L.Linear(3,1))

# %%
net  = rnn.ANN(0, optimizers.Adam(), predictor, F.mean_squared_error)

# %%
net.train(T,X,epochs,n)
# Out:
# epoch: 34
# duration: 0.106281995773
# loss: 0.73045784235

# %%
plt.plot(np.squeeze(net.test(X)))
plt.xlabel('time')
plt.ylabel('output')
